# %% [markdown]
# # ASSIGNMENT-3

# %%
import pandas as pd

# %%
data = pd.read_csv("netflix_data.csv")
data.head()
# Out:
#   show_id     type  title           director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie   7:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 cast        country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#           date_added  release_year  duration  \
# 0    August 14, 2020          2020         4
# 1  December 23, 2016          2016        93
# 2  December 20, 2018          2011        78
# 3  November 16, 2017          2009        80
# 4    January 1, 2020          2008       123
#
# ...

# %% [markdown]
# # Question1: Create a new column in the provided dataset. Column name should be num_of_cast. The assignment was already explained in class. You have to append or add a column in the dataset which contains the total number of cast in that particular movie or Tv-Show.

# %%
data.loc[:,"cast"]
# Out:
# 0       João Miguel, Bianca Comparato, Michel Gomes, R...
# 1       Demián Bichir, Héctor Bonilla, Oscar Serrano, ...
# 2       Tedd Chan, Stella Chung, Henley Hii, Lawrence ...
# 3       Elijah Wood, John C. Reilly, Jennifer Connelly...
# 4       Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...
#                               ...
# 7782    Imad Creidi, Antoinette Turk, Elias Gergi, Car...
# 7783    Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...
# 7784                                              Nasty C
# 7785                           Adriano Zumbo, Rachel Khoo
# 7786                                                  NaN
# Name: cast, Length: 7787, dtype: object

# %%
data.dtypes
# Out:
# show_id         object
# type            object
# title           object
# director        object
# cast            object
# country         object
# date_added      object
# release_year     int64
# duration         int64
# description     object
# genre           object
# dtype: object

# %%
num_cast= [len(i.split(',')) for i in data['cast'].astype(str)]

# %%
data["num_of_cast"]= num_cast

# %%
data
# Out:
#      show_id     type                                    title  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                     7:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7782   s7783    Movie                                     Zozo
# 7783   s7784    Movie                                   Zubaan
# 7784   s7785    Movie                        Zulu Man in Japan
# 7785   s7786  TV Show                    Zumbo's Just Desserts
# 7786   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                director                                               cast  \
# 0                   NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %%
data.groupby
# Out:
# <bound method DataFrame.groupby of      show_id     type                                    title  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                     7:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7782   s7783    Movie                                     Zozo
# 7783   s7784    Movie                                   Zubaan
# 7784   s7785    Movie                        Zulu Man in Japan
# 7785   s7786  TV Show                    Zumbo's Just Desserts
# 7786   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                director                                               cast  \
# 0                   NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %% [markdown]
# # Question 2: In the provided dataset count how many number of tv-shows and movies of each genre are there using group by or whichever other method you see fit.

# %%
data.groupby(["type", "genre"]).size()
# Out:
# type     genre
# Movie    Action                   721
#          Anime Features            19
#          Children                 502
#          Classic Movies            77
#          Comedies                1074
#          Cult Movies               12
#          Documentaries            751
#          Dramas                  1384
#          Horror Movies            244
#          Independent Movies        20
#          International Movies     114
#          LGBTQ Movies               1
#          Music                     17
#          Romantic Movies            3
#          Sci-Fi                    11
#          Sports Movies              1
#          Stand-Up                 321
#          Thrillers                 49
#          Uncategorized             56
# TV Show  Anime Series             148
#          British TV               232
#          Classic                   21
#          Crime TV                 369
#          Docuseries               194
# ...
